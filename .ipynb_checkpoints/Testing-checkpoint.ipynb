# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Load the Data and some minor Cleaning

# %%
df = pd.read_csv('dataset/Gold_Price_Data_Final_Final.csv')

# %%
df.head()
# Out:
#    Price  Year  Month  Day
# 0  281.0  2000      1    4
# 1  283.2  2000      1    5
# 2  281.4  2000      1    6
# 3  281.9  2000      1    7
# 4  281.7  2000      1   10

# %%
df.isnull().any()
# Out:
# Price    False
# Year     False
# Month    False
# Day      False
# dtype: bool

# %%
sns.distplot(df['Price'].dropna())
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Price'].fillna(df['Price'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Price    0
# Year     0
# Month    0
# Day      0
# dtype: int64

# %%
df.describe()
# Out:
#              Price         Year        Month          Day
# count  5706.000000  5706.000000  5706.000000  5706.000000
# mean   1051.334064  2010.812303     6.461619    15.703821
# std     522.375070     6.446924     3.447010     8.763956
# min     255.000000  2000.000000     1.000000     1.000000
# 25%     462.850000  2005.000000     3.000000     8.000000
# 50%    1223.050000  2011.000000     6.000000    16.000000
# 75%    1407.475000  2016.000000     9.000000    23.000000
# max    2121.700000  2022.000000    12.000000    31.000000

# %%
sns.boxplot(df['Price'])
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
from scipy import stats

# %%
z=np.abs(stats.zscore(df))
z
# Out:
#          Price      Year     Month       Day
# 0     1.474805  1.677273  1.584590  1.335567
# 1     1.470594  1.677273  1.584590  1.221453
# 2     1.474040  1.677273  1.584590  1.107339
# 3     1.473082  1.677273  1.584590  0.993225
# 4     1.473465  1.677273  1.584590  0.650884
# ...        ...       ...       ...       ...
# 5701  1.759744  1.735506  0.714194  0.308543
# 5702  1.780995  1.735506  0.714194  0.194429
# 5703  1.775060  1.735506  0.714194  0.262026
# 5704  1.780229  1.735506  0.714194  0.376139
# 5705  1.724517  1.735506  0.714194  0.490253
#
# [5706 rows x 4 columns]

# %%
threshold=3
np.where(z>threshold)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df_no_outliers=df[(z<=3).all(axis=1)]
df_no_outliers
# Out:
#        Price  Year  Month  Day
# 0      281.0  2000      1    4
# 1      283.2  2000      1    5
# 2      281.4  2000      1    6
# 3      281.9  2000      1    7
# 4      281.7  2000      1   10
# ...      ...   ...    ...  ...
# 5701  1970.5  2022      4   13
# 5702  1981.6  2022      4   14
# 5703  1978.5  2022      4   18
# 5704  1981.2  2022      4   19
# 5705  1952.1  2022      4   20
#
# [5706 rows x 4 columns]

# %%
df_no_outliers.shape
# Out:
# (5706, 4)

# %% [markdown]
# # Visualization

# %%
fig=plt.figure(figsize=(5,5))
plt.scatter(df['Day'],df['Price'],color='red')
plt.xlabel('Day')
plt.ylabel('Price')
plt.title('PRICE OF GOLD ON THE BASIS OF DAYS OF A MONTH')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig=plt.figure(figsize=(5,5))
plt.scatter(df['Year'],df['Price'],color='green')
plt.xlabel('Month')
plt.ylabel('Price')
plt.title('PRICE OF GOLD ON THE BASIS OF MONTHS OF A YEAR')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
HEAT MAP

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (18,10))
plt.plot(df['High'])
plt.plot(df['Low'])
plt.legend(['High','Low'])
plt.title('High and Low Prices of Gold', fontsize =20)
# Out:
# Text(0.5, 1.0, 'High and Low Prices of Gold')

# %%
plt.figure(figsize = (18,10))
plt.plot(df['Volume'])
plt.title('Volume', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
df['PriceDiff'] = df['Close'].shift(-1) - df['Close']
df = df.dropna()
print(df['PriceDiff'])
# Out:
# Date
# 2000-01-04    -1.6
# 2000-01-05     0.3
# 2000-01-06     0.5
# 2000-01-07    -0.2
# 2000-01-10     1.7
#               ...
# 2022-04-12     8.6
# 2022-04-13    -9.8
# 2022-04-14    11.5
# 2022-04-18   -27.4
# 2022-04-19    -2.7
# Name: PriceDiff, Length: 5705, dtype: float64

# %%
plt.figure(figsize = (18,10))
plt.plot(df['PriceDiff'])
plt.plot(df['Close'])
plt.legend(['PriceDiff','Close'])
plt.title('Price Difference and Close Price of Gold',fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Price Difference and Close Price of Gold')

# %%
df['MA10'] = df['Close'].rolling(10).mean()
df['MA50'] = df['Close'].rolling(50).mean()
# Out:
# /var/folders/hm/krhxsxmj38xcjkd5gxy0fq780000gn/T/ipykernel_51285/1912615136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MA10'] = df['Close'].rolling(10).mean()
# /var/folders/hm/krhxsxmj38xcjkd5gxy0fq780000gn/T/ipykernel_51285/1912615136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MA50'] = df['Close'].rolling(50).mean()

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
print(adf_test(df['High']))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.549214
# p-value                           0.882050
# #Lags Used                        6.000000
# Number of Observations Used    5698.000000
# Critical Value (1%)              -3.431498
# Critical Value (5%)              -2.862047
# Critical Value (10%)             -2.567040
# dtype: float64
# None

# %%
print(adf_test(df['High'].resample('MS').mean()))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.437622
# p-value                          0.903625
# #Lags Used                       2.000000
# Number of Observations Used    265.000000
# Critical Value (1%)             -3.455270
# Critical Value (5%)             -2.872509
# Critical Value (10%)            -2.572615
# dtype: float64
# None

# %%
gold_month = df.resample('M').mean()
df['Returns'] = df['PriceDiff'] / df['Close']
df = df.dropna()
# Out:
# /var/folders/hm/krhxsxmj38xcjkd5gxy0fq780000gn/T/ipykernel_51285/2043403191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Returns'] = df['PriceDiff'] / df['Close']

# %%
gold_diff = df['Open'].resample('MS').mean() - df['Open'].resample('MS').mean().shift(1)
gold_open_diff = gold_diff.dropna()
gold_open_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.regplot(x = 'High', y = 'PriceDiff', data = df)
# Out:
# <AxesSubplot:xlabel='High', ylabel='PriceDiff'>

# %% [markdown]
# # Seasonal Decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(gold_month.Close, model='additive')
fig = decomposition.plot()
plt.show()

# %%
seasonality = decomposition.seasonal
seasonality.plot(color = 'green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pandas.plotting import lag_plot
lag_plot(df['Volume'].tail(250))
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# # Autocorrelation Plots

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

plot_acf(df['PriceDiff'], lags =20)

# %%
plot_pacf(df['PriceDiff'], lags = 20, method='ols')

# %% [markdown]
# # ARIMA

# %%
from statsmodels.tsa.api import ARIMA

model = ARIMA(df['Close'],order =(0,0,0))
result = model.fit()
print(result.aic)
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 86933.43062932984

# %%
model2 = ARIMA(df['Close'], order=(0,1,0))
result2 = model2.fit()
print(result2.aic)
# Out:
# 49469.91457798425
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model3 = ARIMA(df['Close'], order = (1,0,0))
result3 = model3.fit()
print(result3.aic)
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 49488.81420515418

# %%
model4 = ARIMA(df['Close'], order =(1,1,0))
result4 = model4.fit()
print(result4.aic)
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 49343.54179398628

# %%
model5 = ARIMA(df['Close'], order = (1,1,1))
result5 = model5.fit()
print(result5.aic)
# Out:
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 49167.95432438569

# %%
residuals = pd.DataFrame(result5.resid)
residuals = residuals.iloc[1:]
residuals.describe()
# Out:
#                  0
# count  5655.000000
# mean      0.486004
# std      18.682213
# min    -167.469693
# 25%      -4.162701
# 50%       0.616046
# 75%       6.203455
# max     157.146529

# %%
plt.plot(residuals)

# %%
plot_acf(residuals)

# %%
plot_pacf(residuals, method='ols')

# %%
plt.plot(df['Close'])
plt.plot(residuals)
plt.legend(['Close','Residuals'])

# %% [markdown]
# # KPSS

# %%
from statsmodels.tsa.stattools import kpss

def kpss_test(timeseries):
    print("Results of KPSS Test:")
    kpsstest = kpss(timeseries, regression="c", nlags="auto")
    kpss_output = pd.Series(
        kpsstest[0:3], index=["Test Statistic", "p-value", "Lags Used"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Critical Value (%s)" % key] = value
    print(kpss_output)

# %%
kpss_test(df['High'])
# Out:
# Results of KPSS Test:
# Test Statistic           10.673733
# p-value                   0.010000
# Lags Used                44.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
df['High_diff'] = df['High'] - df['High'].shift(1)
df['High_diff'].dropna().plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
kpss_test(df['High_diff'].dropna())
# Out:
# Results of KPSS Test:
# Test Statistic            0.06951
# p-value                   0.10000
# Lags Used                29.00000
# Critical Value (10%)      0.34700
# Critical Value (5%)       0.46300
# Critical Value (2.5%)     0.57400
# Critical Value (1%)       0.73900
# dtype: float64
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
kpss_test(df['High_diff'].resample('MS').mean().dropna())
# Out:
# Results of KPSS Test:
# Test Statistic           0.091457
# p-value                  0.100000
# Lags Used                4.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
kpss_test(df['High_diff'].resample('MS').std().dropna())
# Out:
# Results of KPSS Test:
# Test Statistic           2.190902
# p-value                  0.010000
# Lags Used                9.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# /Users/waiyankyaw/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
adf_test(df['High_diff'].dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -34.016209
# p-value                           0.000000
# #Lags Used                        5.000000
# Number of Observations Used    5649.000000
# Critical Value (1%)              -3.431508
# Critical Value (5%)              -2.862052
# Critical Value (10%)             -2.567042
# dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.plot(df['High_diff'])
plt.plot(residuals)
plt.legend(['High_diff','Residuals'])
plt.show()

# %% [markdown]
# # PreProcessing and apply RNN + LSTM

# %%
train_df = df['High'].iloc[:-4]

X_train = []
y_train = []

for i in range(2, len(train_df)):
  X_train.append(train_df[i-2:i])
  y_train.append(train_df[i])

# %%
import math
train_len = math.ceil(len(train_df)*0.8)
train_len
# Out:
# 4522

# %%
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation, Dropout, TimeDistributed
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 from tensorflow.keras.layers import LSTM
#       2 from tensorflow.keras.layers import Dense, Activation, Dropout, TimeDistributed
#       3 from tensorflow.keras.models import Sequential
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
X_train, y_train= np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model=Sequential()
model.add(LSTM(50,activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(25))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
model.fit(X_train, y_train, epochs=10, batch_size=100, verbose=2)

# %%
loss = pd.DataFrame(model.history.history)
loss[['loss']].plot()

# %%
test_data = train_df[train_len-2:]
X_val=[]
Y_val=[] 

for i in range(2, len(test_data)):
    X_val.append(test_data[i-2:i])
    Y_val.append(test_data[i])




X_val, Y_val = np.array(X_val), np.array(Y_val)
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1],1))
prediction = model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error
# Know the model error accuracy | the model accuracy 
lstm_train_pred = model.predict(X_train)
lstm_valid_pred = model.predict(X_val)
print('Train rmse:', np.sqrt(mean_squared_error(y_train, lstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_val, lstm_valid_pred)))

# %%
valid = pd.DataFrame(train_df[train_len:])
valid['Predictions']=lstm_valid_pred 
plt.figure(figsize=(16,8))
plt.plot(valid[['High','Predictions']])
plt.legend(['Validation','Predictions'])
plt.show()

# %%
variance = []
for i in range(len(valid)):
  
  variance.append(valid['High'][i]-valid['Predictions'][i])
variance = pd.DataFrame(variance)
variance.describe()
